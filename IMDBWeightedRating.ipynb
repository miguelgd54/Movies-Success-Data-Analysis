# %% [markdown]
# # Analyzing IMDB ratings weighted by votes

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Renamed data from title.ratings.tsv.gz->data.tsv
ratings = pd.read_csv('ratings.tsv',delimiter='\t')
# Renamed data from title.basics.tsv.gz->data.tsv
basics = pd.read_csv('basics.tsv', delimiter='\t')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Remove all things that arent movies
basics = basics[basics['titleType'] == "movie"]
# Remove all adult titles
basics = basics[basics['isAdult'] == 0]
# Remove unnecessary columns
basics = basics.drop(['titleType','originalTitle','isAdult','startYear','endYear','runtimeMinutes','genres'],axis=1)

# %%
# Do a inner join on movies that have both ratings and basic info
df = pd.merge(basics, ratings, on='tconst', how='inner')
df = df.drop(['tconst'], axis=1)

# %%
# Drop movies with too little votes
# df = df[df['numVotes']>50000]
# Add a new column with weighted ratings based on minimum votes
minVote = 30000

# Scroll down to the bottom of the following link to check how the weighted rating was calculated
# https://help.imdb.com/article/imdb/track-movies-tv/faq-for-imdb-ratings/G67Y87TFYYP6TWAV?ref_=helpsect_pro_2_4#
df = df.assign(weighted_ratings=((df['numVotes']/(df['numVotes']+minVote))*df['averageRating'])+(minVote/(df['numVotes']+minVote))*df['averageRating'].mean())

df.sort_values(by=['weighted_ratings'], ascending=False)
# Out:
#                                              primaryTitle  averageRating  \
# 57489                            The Shawshank Redemption            9.3
# 33706                                       The Godfather            9.2
# 121390                                    The Dark Knight            9.0
# 35550                              The Godfather: Part II            9.0
# 57345                                        Pulp Fiction            8.9
# 72261       The Lord of the Rings: The Return of the King            8.9
# 55960                                    Schindler's List            8.9
# 203573                                    The Mountain II            9.6
# 28253                      The Good, the Bad and the Ugly            8.9
# 21167                                        12 Angry Men            8.9
# 142748                                          Inception            8.8
# 66246                                          Fight Club            8.8
# 56779                                        Forrest Gump            8.8
# 62143   The Lord of the Rings: The Fellowship of the Ring            8.8
# 40812      Star Wars: Episode V - The Empire Strikes Back            8.8
# 65262                                          The Matrix            8.7
# 72262               The Lord of the Rings: The Two Towers            8.7
# 51532                                          Goodfellas            8.7
# 36691                     One Flew Over the Cuckoo's Nest            8.7
# 58976                                               Se7en            8.6
# 126797                                       Interstellar            8.6
# 38604                  Star Wars: Episode IV - A New Hope            8.6
# 53303                            The Silence of the Lambs            8.6
# 62200                                 Saving Private Ryan            8.6
# 59171                                  The Usual Suspects            8.6
# 57085                              Léon: The Professional            8.6
# 152609                                   The Intouchables            8.6
# 102368                                        City of God            8.6
# 88554                                       Spirited Away            8.6
# 60981                                   Life Is Beautiful            8.6
# ...                                                   ...            ...
# 61809                             Speed 2: Cruise Control            3.8
# 111739                                         BloodRayne            2.9
# 109529                                           The Room            3.6
# 196800                                    The Emoji Movie            3.0
# 47953                                   Jaws: The Revenge            2.9
# 125857                                      Scary Movie 5            3.5
# 105472                               From Justin to Kelly            2.1
# 169617                               Fifty Shades of Grey            4.1
# 126505                                      Jack and Jill            3.4
# 93809                        Superbabies: Baby Geniuses 2            2.0
# 174786                                    Celal and Ceren            2.6
# 193665                                  Code Name: K.O.Z.            1.6
# 121167                                         Date Movie            2.8
# 60909                                      Batman & Robin            3.7
# 109694                                  Alone in the Dark            2.3
# 102441                                  House of the Dead            2.0
# 103958                                           Catwoman            3.3
# 28569                            Manos: The Hands of Fate            1.9
# 99559                                               Gigli            2.4
# 126140                            The Hottie & the Nottie            1.9
# 108600                                    Son of the Mask            2.2
# 134169                              Dragonball: Evolution            2.6
# 209926                     Cumali Ceber: Allah Seni Alsin            1.3
# 76693                                   Battlefield Earth            2.4
# 174361                                             Gunday            2.1
# 133447                                  Meet the Spartans            2.7
# 125979                                         Epic Movie            2.3
# 204673                                               Reis            1.8
# 137212                                     Disaster Movie            1.9
# 153346                     Justin Bieber: Never Say Never            1.6
#
#         numVotes  weighted_ratings
# 57489    1918705          9.253368
# 33706    1311353          9.134490
# 121390   1890573          8.957371
# 35550     905401          8.912474
# 57345    1499007          8.848416
# 72261    1369719          8.843652
# 55960     987600          8.822492
# 203573     94580          8.798332
# 28253     567626          8.768025
# 21167     529201          8.758956
# 142748   1678493          8.755591
# 66246    1536494          8.751566
# 56779    1450796          8.748763
# 62143    1389456          8.746549
# 40812     964234          8.723688
# 65262    1378362          8.648258
# 72262    1239903          8.642616
# 51532     826381          8.614907
# 36691     764604          8.608292
# 58976    1169545          8.541751
# 126797   1145622          8.540566
# 38604    1036476          8.534483
# 53303    1023011          8.533646
# 62200    1010027          8.532817
# 59171     836739          8.519385
# 57085     835141          8.519236
# 152609    603174          8.489648
# 102368    595827          8.488353
# 88554     495422          8.467018
# 60981     494710          8.466837
# ...          ...               ...
# 61809      65309          4.577766
# 111739     31729          4.538260
# 109529     57358          4.517239
# 196800     35352          4.501532
# 47953      34145          4.476555
# 125857     55573          4.471430
# 105472     24068          4.414274
# 169617    259528          4.324946
# 126505     66426          4.293205
# 93809      27159          4.241609
# 174786     38981          4.196500
# 193665     26008          4.101931
# 121167     52856          4.056736
# 60909     206251          4.026467
# 109694     39272          4.019716
# 102441     33613          4.014182
# 103958     95136          4.012250
# 28569      32441          4.000033
# 99559      43287          3.984567
# 126140     34440          3.934887
# 108600     45491          3.817784
# 134169     62101          3.795732
# 209926     34401          3.615618
# 76693      69172          3.570977
# 174361     55383          3.565492
# 133447     94028          3.563742
# 125979     94625          3.255893
# 204673     71291          3.124186
# 137212     79109          3.101809
# 153346     74777          2.937394
#
# [211390 rows x 4 columns]
